# %% [markdown]
# # Clase 6 — Taller integrador: filtrar y ordenar datos
# **Introducción a la ciencia de datos e IA con Python · FLACSO Ecuador**
#
# **Nombre:** ____________________  **Fecha:** ____________________
#
# Este cuaderno reúne lo que hemos trabajado en las clases 1 a 5 y añade filtros y ordenamiento. **Las celdas de código están vacías para que tú las completes.** Si tienes poco tiempo, realiza primero los ejercicios marcados **★**.
#
# 1. En Colab selecciona **Archivo → Guardar una copia en Drive**.
# 2. Ejecuta las celdas en orden. Escribe tus respuestas a las preguntas en las celdas de texto.
# 3. Si aparece un error, lee la última línea y comprueba nombres de variables, comillas, paréntesis y sangría.
#
# **Datos:** [Gapminder en el repositorio de Plotly](https://github.com/plotly/datasets/blob/master/gapminderDataFiveYear.csv). Son observaciones históricas de 1952 a 2007; **no representan la situación actual**. Una fila corresponde a un país en un año. Algunas cifras son estimaciones y las comparaciones no demuestran causas.
#
# | Columna | Qué indica |
# |---|---|
# | `country` | País |
# | `year` | Año |
# | `pop` | Población |
# | `continent` | Continente |
# | `lifeExp` | Esperanza de vida al nacer, en años |
# | `gdpPercap` | PIB por persona en la serie histórica |

# %% [markdown]
# ## A. Recordatorio de Python
# Realiza esta sección como calentamiento. Las respuestas van en las celdas vacías.

# %% [markdown]
# ### 1. Mensajes y variables
# Guarda tu nombre, una ciudad y el año 2007 en tres variables. Muestra una frase con `print()` y una cadena `f"..."`.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 2. Tipos de datos
# Crea un texto, un entero, un decimal y un booleano. Usa `type()` para consultar cada tipo. ¿Qué tipo esperas que tenga `year`?

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 3. Listas, diccionarios y acceso
# Crea una lista con tres países que quieras investigar. Después crea un diccionario con las claves `pais`, `anio` y `pregunta`. Muestra el segundo elemento de la lista y el valor de `pais` en el diccionario.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 4. Ciclo y condición
# Recorre tu lista de países con `for`. Dentro del ciclo, usa `if` para mostrar un mensaje especial cuando el país sea `"Ecuador"`. Revisa los dos puntos y la sangría.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 5. Función ★
# Escribe una función `diferencia(a, b)` que devuelva la resta entre dos números. Pruébala con 2007 y 1952. ¿Cuántos años separan esas observaciones?

# %%
# Escribe tu código aquí

# %% [markdown]
# ## B. Cargar y conocer una base de datos

# %% [markdown]
# ### 6. Importar y cargar ★
# Importa pandas como `pd`. Con `pd.read_csv()` carga esta dirección y guarda el resultado en `df`:
#
# `https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv`
#
# Muestra `df` para comprobar que funcionó.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 7. Primer vistazo ★
# Muestra cinco primeras filas y cinco últimas filas. ¿Qué representa una fila? ¿Todas las columnas tienen el mismo tipo de dato?

# %%
# Escribe tu código aquí

# %% [markdown]
# **Respuesta:**
#
# - Una fila representa...
# - Las columnas...

# %% [markdown]
# ### 8. Dimensiones y columnas ★
# Muestra el número de filas y columnas por separado con `shape`. Después muestra la lista de nombres de columnas. Recuerda: `shape` y `columns` son atributos, sin paréntesis.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 9. Estructura, estadísticas y categorías
# Usa `info()` y `describe()`. Cuenta las filas por continente con `value_counts()`. ¿Por qué `value_counts()` cuenta **filas** y no necesariamente **países distintos**?

# %%
# Escribe tu código aquí

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 10. Valores faltantes
# Cuenta los valores faltantes de cada columna con `isna()` y `sum()`. ¿Hay algún faltante en esta copia de la base? Guarda esta observación para la clase 7.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## C. Seleccionar, filtrar y ordenar
# **Pregunta guía:** ¿qué podemos decir de Ecuador en 2007 y cómo se compara con otros registros de América? Antes de cada celda, escribe en palabras qué registros esperas obtener.

# %% [markdown]
# ### 11. Seleccionar columnas ★
# Muestra únicamente las columnas `country`, `year` y `lifeExp`. Primero selecciona las tres; luego muestra solo las primeras cinco filas.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 12. Un filtro ★
# Con `==`, guarda en `ecuador` solo las filas cuyo país sea Ecuador. Muestra el resultado. ¿Cuántos años aparecen?

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 13. Dos condiciones ★
# Guarda en `ecuador_2007` la fila de Ecuador correspondiente a 2007. Usa `&` y coloca **cada condición entre paréntesis**. Muestra país, año, población y esperanza de vida.

# %%
# Escribe tu código aquí

# %% [markdown]
# **Respuesta:** En 2007, según esta base, la esperanza de vida al nacer registrada para Ecuador fue...

# %% [markdown]
# ### 14. Filtrar un continente y un año ★
# Guarda en `america_2007` solo las filas cuyo continente sea `"Americas"` y año sea `2007`. Muestra cuántas filas quedaron con `shape`. ¿Qué representa ahora una fila?

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 15. Comparar números ★
# Dentro de `america_2007`, muestra los registros donde `lifeExp` sea menor que 70. Cuenta cuántas filas cumplen la condición. ¿Cambiaría el resultado si usaras `<=`?

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 16. Ordenar ★
# Ordena `america_2007` por `lifeExp` de mayor a menor. Muestra las primeras cinco filas con `head()`. Después ordena de menor a mayor y muestra las primeras cinco. Consulta el argumento `ascending`.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 17. Buscar una posición
# En la tabla ordenada de mayor a menor, identifica la posición de Ecuador. Pista: usa `reset_index(drop=True)` si deseas posiciones consecutivas y recuerda que Python comienza a contar desde cero. Escribe también la posición de forma comprensible para una persona (primera, segunda, etc.).

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 18. Filtrar varios países
# Usa `isin()` para seleccionar Ecuador, Perú y Bolivia dentro de `america_2007`. Ordena esas filas primero por población y luego por esperanza de vida. ¿El orden coincide?

# %%
# Escribe tu código aquí

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ### 19. Dos condiciones numéricas
# Encuentra los registros de América en 2007 con población superior a 10 millones **y** esperanza de vida superior a 75 años. Muestra país, población y esperanza de vida. ¿Cuántos registros son?

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 20. Elegir una pregunta propia ★
# Formula una pregunta que pueda responderse con columnas de esta base. Escribe primero la pregunta en palabras; después filtra, selecciona y ordena la información necesaria.

# %% [markdown]
# **Mi pregunta:**
#
# **Columnas necesarias:**
#
# **Filtros necesarios:**

# %%
# Escribe tu código aquí

# %% [markdown]
# ## D. Repaso de agrupaciones y gráficos (si queda tiempo)
# Estas herramientas ya aparecieron en la clase 4. Esta sección es optativa para quienes terminen antes.

# %% [markdown]
# ### 21. Agrupar
# Con los registros de 2007, agrupa por continente y calcula la **mediana** de `lifeExp`. Ordena el resultado de mayor a menor. ¿Cuántos registros contribuyen a cada continente? Un promedio o mediana de países no equivale a la esperanza de vida del conjunto de personas del continente.

# %%
# Escribe tu código aquí

# %% [markdown]
# ### 22. Un gráfico de barras
# A partir de la tabla del ejercicio anterior, crea un gráfico de barras con el nombre del continente y la mediana. Incluye título y nombre del eje vertical. Puedes utilizar `plot(kind="bar")` o matplotlib, como en la clase 4.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## E. Comunicar un hallazgo ★
# En una celda de texto escribe **tres frases**:
#
# 1. Tu pregunta y el grupo que analizaste.
# 2. Un resultado con cifra, unidad y año.
# 3. Una limitación: la base termina en 2007, los países no representan por sí mismos a cada persona y una diferencia observada no demuestra su causa.
#
# **Mi conclusión:**

# %% [markdown]
# ### Lista de comprobación
# - [ ] Puedo reconocer variables, listas, diccionarios, `for`, `if` y funciones.
# - [ ] Puedo cargar un CSV y explicar qué representa una fila.
# - [ ] Puedo usar `head()`, `shape`, `info()`, `describe()` y `value_counts()`.
# - [ ] Puedo seleccionar columnas, combinar filtros y ordenar registros.
# - [ ] Puedo explicar el resultado y una limitación de mi análisis.
#
# **Para la próxima clase:** ¿qué haríamos si hubiera registros duplicados o valores faltantes?
